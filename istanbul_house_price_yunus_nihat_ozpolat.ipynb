# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_emlak = pd.read_csv("Real Estate in ISTANBUL (Emlakjet).csv",index_col=0)

# %%
data_emlak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2983 entries, 2003 to 452
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   İlan_Güncelleme_Tarihi  2983 non-null   object
#  1   Kategorisi              2983 non-null   object
#  2   Brüt_Metrekare          2983 non-null   int64
#  3   Binanın_Yaşı            2983 non-null   object
#  4   Binanın_Kat_Sayısı      2983 non-null   int64
#  5   Kullanım_Durumu         2983 non-null   object
#  6   Yatırıma_Uygunluk       2983 non-null   object
#  7   Eşya_Durumu             2983 non-null   object
#  8   Banyo_Sayısı            2983 non-null   object
#  9   İlan_Oluşturma_Tarihi   2983 non-null   object
#  10  Türü                    2983 non-null   object
#  11  Net_Metrekare           2983 non-null   int64
#  12  Oda_Sayısı              2983 non-null   object
#  13  Bulunduğu_Kat           2983 non-null   object
# ...

# %%
import missingno as mso
mso.bar(data_emlak)
# Eksik verimizin olmadığını görüyoruz
# Out:
# <AxesSubplot: >

# %%
data_emlak.duplicated().any() # Tekrar eden veri olduğu görüldü
# Out:
# True

# %%
data_emlak[data_emlak.duplicated()] # Tekrar eden verinin hangisi olduğu tespit edildi
# Out:
#               İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare Binanın_Yaşı  \
# İlan_Numarası
# 2840                  08 Şubat 2022    Satılık              155    0 (Yeni)
#
#                Binanın_Kat_Sayısı        Kullanım_Durumu Yatırıma_Uygunluk  \
# İlan_Numarası
# 2840                            5  Mülk Sahibi Oturuyor        Bilinmiyor
#
#               Eşya_Durumu Banyo_Sayısı İlan_Oluşturma_Tarihi  ...  \
# İlan_Numarası                                                 ...
# 2840                  Yok           2         08 Şubat 2022   ...
#
#               Site_İçerisinde  Takas  Fiyat_Durumu   Fiyatı         İl  \
# İlan_Numarası
# 2840                    Hayır    Var  Genel Fiyat   1750000  İstanbul
#
#                        İlçe                    Mahalle           yaka  \
# İlan_Numarası
# 2840            Beylikdüzü    Adnan Kahveci Mahallesi   Avrupa Yakası
#
#               Yaşam_endeksi   Nüfus
# İlan_Numarası
# 2840                  0.025 398.122
#
# ...

# %%
data_emlak.drop_duplicates(keep='first',inplace=True)
data_emlak.duplicated().any()
# Tekrar eden veri silindi
# Out:
# False

# %%
data_emlak.describe()
# Out:
#        Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare         Fiyatı  \
# count        2982.000            2982.000       2982.000       2982.000
# mean          169.348               8.671        145.355    5222729.738
# std           373.424               7.092        370.544   37173351.474
# min            35.000               1.000          1.000     169000.000
# 25%           100.000               4.000         84.000     870000.000
# 50%           130.000               5.000        106.000    1650000.000
# 75%           180.000              11.000        150.000    3811250.000
# max         13500.000              44.000      13499.000 1800000000.000
#
#        Yaşam_endeksi    Nüfus
# count       2982.000 2982.000
# mean           0.212  512.198
# std            0.402  206.844
# min           -0.194  178.938
# 25%           -0.152  398.122
# 50%            0.053  503.243
# 75%            0.613  605.300
# max            0.911  977.489

# %%
data_emlak.head()
# Out:
#               İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  Binanın_Yaşı  \
# İlan_Numarası
# 2003                  02 Şubat 2022    Satılık              190         5-10
# 166                    14 Ocak 2022    Satılık              300  21 Ve Üzeri
# 167                    14 Ocak 2022    Satılık              350  21 Ve Üzeri
# 115                    06 Ocak 2022    Satılık              450         5-10
# 2879                  08 Şubat 2022    Satılık              160  21 Ve Üzeri
#
#                Binanın_Kat_Sayısı        Kullanım_Durumu Yatırıma_Uygunluk  \
# İlan_Numarası
# 2003                           20       Kiracı Oturuyor        Bilinmiyor
# 166                             2       Kiracı Oturuyor        Bilinmiyor
# 167                             3  Mülk Sahibi Oturuyor        Bilinmiyor
# 115                             4       Kiracı Oturuyor        Bilinmiyor
# 2879                            2  Mülk Sahibi Oturuyor        Bilinmiyor
#
# ...

# %%
data_emlak.İlçe.value_counts()
# Hangi ilçede kaç ilan olduğuna bakıyoruz.
# Out:
#  Başakşehir       336
#  Kadıköy          334
#  Maltepe          331
#  Bakırköy         277
#  Bağcılar         274
#  Pendik           227
#  Avcılar          225
#  Beşiktaş         222
#  Esenyurt         202
#  Sarıyer          194
#  Beylikdüzü       186
#  Bahçelievler     171
#  Şişli              3
# Name: İlçe, dtype: int64

# %%
data_emlak.İlçe.value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %%
data_emlak.Türü.value_counts()
# Veri setimizdeki bütün verilerin bizim istediğimiz gibi konut türünde olduğunu görüyoruz.
# Out:
# Konut     2982
# Name: Türü, dtype: int64

# %%
data_emlak.Kategorisi.value_counts()
# Veri setimizde istediğimiz gibi bütün konutlar Satılık kategorisinde.
# Out:
# Satılık     2982
# Name: Kategorisi, dtype: int64

# %%
data_emlak.Net_Metrekare.describe()
# Out:
# count    2982.000
# mean      145.355
# std       370.544
# min         1.000
# 25%        84.000
# 50%       106.000
# 75%       150.000
# max     13499.000
# Name: Net_Metrekare, dtype: float64

# %%
data_emlak.Net_Metrekare.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of İlan_Numarası
# 2003    168
# 166     270
# 167     320
# 115     400
# 2879    140
#        ...
# 453     400
# 448     145
# 451     170
# 454     800
# 452     235
# Name: Net_Metrekare, Length: 2982, dtype: int64>

# %%
data_emlak.Fiyatı.value_counts()
# Out:
# 1500000     42
# 1250000     41
# 1350000     41
# 1100000     38
# 1300000     35
#             ..
# 2940000      1
# 12300000     1
# 6650000      1
# 7800000      1
# 7850000      1
# Name: Fiyatı, Length: 770, dtype: int64

# %%
data_emlak.Oda_Sayısı.value_counts()
# Veri setimizdeki evlerin oda sayılarını saydırıyoruz.
# Out:
# 2+1        1118
# 3+1         866
# 1+1         257
# 4+1         236
# 4+2         111
# 5+2          75
# 5+1          72
# 3+2          62
# Stüdyo       29
# 6+2          28
# 8+ Oda       27
# 3.5+1        20
# 2+2          17
# 6+1          15
# 4.5+1        11
# 1 Oda         9
# 2.5+1         8
# 5+3           6
# 7+2           5
# 7+1           5
# 1.5+1         2
# 6+4           1
# 2+0           1
# 6+3           1
# Name: Oda_Sayısı, dtype: int64

# %%
data_emlak.Oda_Sayısı.value_counts().plot.barh()
# Bu sayıları bir de grafik ile gözlemleyelim.
# Out:
# <AxesSubplot: >

# %%
oda_sayisi = data_emlak['Oda_Sayısı']

data_emlak.loc[oda_sayisi == '6+3 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '2+0 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '4+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '5+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '5+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '3+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == 'Stüdyo ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '6+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '8+ Oda ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '3.5+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '2+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '6+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '4.5+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '1 Oda ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '2.5+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '5+3 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '7+2 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '7+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '1.5+1 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '6+4 ', 'Oda_Sayısı']='Diğer'
data_emlak.loc[oda_sayisi == '2+0 ', 'Oda_Sayısı']='Diğer'

# %%
data_emlak['Oda_Sayısı'].value_counts()
# Out:
# 2+1      1118
# 3+1       866
# Diğer     505
# 1+1       257
# 4+1       236
# Name: Oda_Sayısı, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Oda_Sayısı.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Oda_Sayısı", fontsize = 15)
# Out:
# Text(0, 0.5, 'Oda_Sayısı')

# %%
data_emlak.Binanın_Yaşı.value_counts()
# Bina yaşlarını saydırıyoruz
# Out:
# 0 (Yeni)        766
# 5-10            607
# 21 Ve Üzeri     542
# 4               335
# 11-15           227
# 3               196
# 2               142
# 1                96
# 16-20            71
# Name: Binanın_Yaşı, dtype: int64

# %%
binanin_yasi = data_emlak['Binanın_Yaşı']

data_emlak.loc[binanin_yasi =='0 (Yeni) ', 'Binanın_Yaşı']='0-4'
data_emlak.loc[binanin_yasi =='1 ', 'Binanın_Yaşı']='0-4'
data_emlak.loc[binanin_yasi =='2 ','Binanın_Yaşı']='0-4'
data_emlak.loc[binanin_yasi =='3 ','Binanın_Yaşı']='0-4'
data_emlak.loc[binanin_yasi =='4 ','Binanın_Yaşı']='0-4'

# %%
data_emlak.Binanın_Yaşı.value_counts()
# Out:
# 0-4             1535
# 5-10             607
# 21 Ve Üzeri      542
# 11-15            227
# 16-20             71
# Name: Binanın_Yaşı, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Binanın_Yaşı.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Binanın Yaşı", fontsize = 15)
# Bina yaşlarını daha kolay analiz edebilmek için görselleştiriyoruz
# Out:
# Text(0, 0.5, 'Binanın Yaşı')

# %%
data_emlak.Bulunduğu_Kat.value_counts()
# İlandaki konutların bulundukları katı saydırıyoruz.
# Out:
# 1. Kat              349
# 2. Kat              347
# 4. Kat              338
# 3. Kat              321
# Düz Giriş           246
# Bahçe Katı          240
# 5. Kat              212
# Yüksek Giriş        172
# 7. Kat              101
# 6. Kat               94
# 8. Kat               72
# 10. Kat              68
# 9. Kat               58
# 11. Kat              41
# 12. Kat              35
# 14. Kat              31
# 13. Kat              23
# 16. Kat              22
# 15. Kat              21
# Çatı Katı            21
# 30-40. Kat           18
# 17. Kat              15
# 20. Kat              15
# 19. Kat              13
# 21. Kat              13
# Kot 1 (-1). Kat      11
# 10-20. Kat           10
# 22. Kat               9
# 26. Kat               9
# Villa Tipi            8
# 23. Kat               8
# 18. Kat               7
# Kot 2 (-2). Kat       7
# Müstakil              6
# Çatı Dubleks          5
# Tam Bodrum            4
# 24. Kat               3
# 25. Kat               2
# ...

# %%
bulundugu_kat = data_emlak['Bulunduğu_Kat']

data_emlak.loc[bulundugu_kat == 'Yüksek Giriş ', 'Bulunduğu_Kat'] = 'Giriş'
data_emlak.loc[bulundugu_kat == 'Düz Giriş ', 'Bulunduğu_Kat'] = 'Giriş'

data_emlak.loc[bulundugu_kat == '10. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '11. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '12. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '13. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '14. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '15. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '16. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '17. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '18. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '19. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '20. Kat ', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '10-10-20', 'Bulunduğu_Kat'] = '10-20'
data_emlak.loc[bulundugu_kat == '10-20. Kat ', 'Bulunduğu_Kat'] = '10-20'

data_emlak.loc[bulundugu_kat == '21. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '22. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '23. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '24. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '25. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '26. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '27. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '28. Kat ', 'Bulunduğu_Kat'] = '21-29'
data_emlak.loc[bulundugu_kat == '29. Kat ', 'Bulunduğu_Kat'] = '21-29'

data_emlak.loc[bulundugu_kat == '30. Kat ', 'Bulunduğu_Kat'] = '30-40'
data_emlak.loc[bulundugu_kat == '30-40. Kat ', 'Bulunduğu_Kat'] = '30-40'

data_emlak.loc[bulundugu_kat == 'Kot 1 (-1). Kat ', 'Bulunduğu_Kat'] = '-1'
data_emlak.loc[bulundugu_kat == 'Kot 2 (-2). Kat ', 'Bulunduğu_Kat'] = '-2'
data_emlak.loc[bulundugu_kat == 'Kot 3 (-3). Kat ', 'Bulunduğu_Kat'] = '-3'

data_emlak.loc[bulundugu_kat == '6. Kat ', 'Bulunduğu_Kat'] = '6-9'
data_emlak.loc[bulundugu_kat == '7. Kat ', 'Bulunduğu_Kat'] = '6-9'
data_emlak.loc[bulundugu_kat == '8. Kat ', 'Bulunduğu_Kat'] = '6-9'
data_emlak.loc[bulundugu_kat == '9. Kat ', 'Bulunduğu_Kat'] = '6-9'

data_emlak.loc[bulundugu_kat == 'Kot 3 (-3). Kat ', 'Bulunduğu_Kat'] = '-3'
data_emlak.loc[bulundugu_kat == 'Kot 2 (-2). Kat ', 'Bulunduğu_Kat'] = '-2'
data_emlak.loc[bulundugu_kat == 'Kot 1 (-1). Kat ', 'Bulunduğu_Kat'] = '-1'

data_emlak.loc[bulundugu_kat == '1. Kat ', 'Bulunduğu_Kat'] = '1'
data_emlak.loc[bulundugu_kat == '2. Kat ', 'Bulunduğu_Kat'] = '2'
data_emlak.loc[bulundugu_kat == '3. Kat ', 'Bulunduğu_Kat'] = '3'
data_emlak.loc[bulundugu_kat == '4. Kat ', 'Bulunduğu_Kat'] = '4'
data_emlak.loc[bulundugu_kat == '5. Kat ', 'Bulunduğu_Kat'] = '5'

bulundugu_kat.value_counts()
# Out:
# Giriş            418
# 1                349
# 2                347
# 4                338
# 6-9              325
# 3                321
# 10-20            301
# Bahçe Katı       240
# 5                212
# 21-29             47
# Çatı Katı         21
# 30-40             20
# -1                11
# Villa Tipi         8
# -2                 7
# Müstakil           6
# Çatı Dubleks       5
# Tam Bodrum         4
# -3                 2
# Name: Bulunduğu_Kat, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Bulunduğu_Kat.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Bulunduğu_Kat", fontsize = 15)
# Out:
# Text(0, 0.5, 'Bulunduğu_Kat')

# %%
data_emlak.Binanın_Kat_Sayısı.value_counts()
# Konutların bulunduğu binadaki kat sayısını saydırıyoruz
# Out:
# 4     707
# 5     658
# 3     197
# 6     194
# 7     122
# 30    116
# 9     101
# 14     95
# 10     93
# 15     92
# 8      82
# 11     64
# 12     62
# 2      53
# 13     40
# 17     38
# 16     35
# 18     34
# 24     34
# 20     28
# 25     25
# 19     20
# 22     15
# 27     14
# 29     14
# 23     10
# 28      9
# 26      9
# 21      9
# 1       8
# 34      2
# 44      1
# 33      1
# Name: Binanın_Kat_Sayısı, dtype: int64

# %%
data_emlak.Fiyatı.value_counts()
# Out:
# 1500000     42
# 1250000     41
# 1350000     41
# 1100000     38
# 1300000     35
#             ..
# 2940000      1
# 12300000     1
# 6650000      1
# 7800000      1
# 7850000      1
# Name: Fiyatı, Length: 770, dtype: int64

# %%
kat = data_emlak['Binanın_Kat_Sayısı']

for i in range(45):
  if(i<6):
    data_emlak.loc[kat == i, 'Binanın_Kat_Sayısı'] = '1-5'
  elif(6<=i<11):
    data_emlak.loc[kat == i, 'Binanın_Kat_Sayısı'] = '6-10'
  elif(11<=i<21):
    data_emlak.loc[kat == i, 'Binanın_Kat_Sayısı'] = '11-20'
  elif(21<=i<31):
    data_emlak.loc[kat == i, 'Binanın_Kat_Sayısı'] = '21-30'
  else: 
    data_emlak.loc[kat == i, 'Binanın_Kat_Sayısı'] = '30-44'

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Binanın_Kat_Sayısı.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Binanın Kat Sayısı", fontsize = 15)
# Out:
# Text(0, 0.5, 'Binanın Kat Sayısı')

# %%
data_emlak.Isıtma_Tipi.value_counts()
# Önemli verilerden biri olan konutun ısıtma tipini gözlemliyoruz
# Out:
# Doğalgaz          2872
# Yerden Isıtma       74
# Isıtma Yok          20
# Klimalı              8
# Sobalı               8
# Name: Isıtma_Tipi, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Isıtma_Tipi.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Isınma", fontsize = 15)
# Görselleştirdiğimizde verilerimizdeki konutların %96.3'ünün doğalgaz ile ısındığını görüyoruz.
# Out:
# Text(0, 0.5, 'Isınma')

# %%
data_emlak.Banyo_Sayısı.value_counts()
# Out:
# 1               1414
# 2               1146
# 3                232
# 4                 69
# Yok               28
# 5                 25
# 6+                24
# Var               22
# Genel Fiyat       19
# 28 M2              1
# 1075               1
# 15                 1
# Name: Banyo_Sayısı, dtype: int64

# %%
banyo_sayisi = data_emlak['Banyo_Sayısı']

data_emlak.loc[banyo_sayisi == 'Yok ', 'Banyo_Sayısı'] = '0'
data_emlak.loc[banyo_sayisi == 'Var ', 'Banyo_Sayısı'] = '1'
data_emlak.loc[banyo_sayisi == 'Genel Fiyat ', 'Banyo_Sayısı'] = '2'
data_emlak.loc[banyo_sayisi == '28 M2 ', 'Banyo_Sayısı'] = '2'
data_emlak.loc[banyo_sayisi == '1075 ', 'Banyo_Sayısı'] = '2'
data_emlak.loc[banyo_sayisi == '6+ ', 'Banyo_Sayısı'] = '6+'
data_emlak.loc[banyo_sayisi == '15 ', 'Banyo_Sayısı'] = '6+'
data_emlak.loc[banyo_sayisi == '1 ', 'Banyo_Sayısı'] = '1'
data_emlak.loc[banyo_sayisi == '2 ', 'Banyo_Sayısı'] = '2'

# %%
data_emlak.Banyo_Sayısı.value_counts()
# Out:
# 1     1436
# 2     1167
# 3      232
# 4       69
# 0       28
# 5       25
# 6+      25
# Name: Banyo_Sayısı, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))
data_emlak.Banyo_Sayısı.value_counts().plot(kind = 'pie',autopct='%.1f%%');
plt.ylabel("Banyo_Sayısı", fontsize = 15)
# Out:
# Text(0, 0.5, 'Banyo_Sayısı')

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Site_İçerisinde.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Site Durumu");

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Eşya_Durumu.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Eşya Durumu");

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Kullanım_Durumu.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Kullanım Durumu");

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Krediye_Uygunluk.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Kredi Durumu");

# %%
data_emlak['Krediye_Uygunluk'].value_counts()
# Out:
# KREDIYE UYGUN           2604
# Krediye Uygun Değil      363
# Bilinmiyor                15
# Name: Krediye_Uygunluk, dtype: int64

# %%
krediye_uygunluk = data_emlak['Krediye_Uygunluk']

data_emlak.loc[krediye_uygunluk =='Bilinmiyor ', 'Krediye_Uygunluk']='Krediye Uygun Değil '

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Krediye_Uygunluk.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Kredi Durumu");

# %%
data_emlak.Yatırıma_Uygunluk.value_counts()
# Out:
# Bilinmiyor         2790
# Hayır               153
# Yatırıma Uygun       24
# Evet                 15
# Name: Yatırıma_Uygunluk, dtype: int64

# %%
data_emlak["Yatırıma_Uygunluk"] = data_emlak["Yatırıma_Uygunluk"].str.replace('Evet', 'Yatırıma Uygun',regex=True)
data_emlak["Yatırıma_Uygunluk"] = data_emlak["Yatırıma_Uygunluk"].str.replace('Hayır', 'Yatırıma Uygun Değil',regex=True)
fig = plt.figure(figsize=(20,5))
data_emlak.Yatırıma_Uygunluk.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Yatırım Durumu");

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Takas.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Takas");

# %%
data_emlak.Takas.value_counts()
# Out:
# Var    2982
# Name: Takas, dtype: int64

# %%
sns.lmplot(x='Fiyatı', y='Brüt_Metrekare', data=data_emlak)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x='Kullanım_Durumu', data=data_emlak)
# Out:
# <AxesSubplot: xlabel='Kullanım_Durumu', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x = "Binanın_Yaşı", y = "Fiyatı", data = data_emlak)
# Out:
# <AxesSubplot: xlabel='Binanın_Yaşı', ylabel='Fiyatı'>

# %%
data_emlak.Fiyat_Durumu.value_counts()
# Out:
# Genel Fiyat     2873
# Birim Fiyat       90
# Hayır             15
# Evet               4
# Name: Fiyat_Durumu, dtype: int64

# %%
fig = plt.figure(figsize=(20,5))
data_emlak.Fiyat_Durumu.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Fiyat_Durumu");

# %%
data_emlak.columns
# Out:
# Index(['İlan_Güncelleme_Tarihi', 'Kategorisi', 'Brüt_Metrekare',
#        'Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
#        'Yatırıma_Uygunluk', 'Eşya_Durumu', 'Banyo_Sayısı',
#        'İlan_Oluşturma_Tarihi', 'Türü', 'Net_Metrekare', 'Oda_Sayısı',
#        'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
#        'Takas', 'Fiyat_Durumu', 'Fiyatı', 'İl', 'İlçe', 'Mahalle', 'yaka',
#        'Yaşam_endeksi', 'Nüfus'],
#       dtype='object')

# %%
data_emlak.head()
# Out:
#               İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  Binanın_Yaşı  \
# İlan_Numarası
# 2003                  02 Şubat 2022    Satılık              190         5-10
# 166                    14 Ocak 2022    Satılık              300  21 Ve Üzeri
# 167                    14 Ocak 2022    Satılık              350  21 Ve Üzeri
# 115                    06 Ocak 2022    Satılık              450         5-10
# 2879                  08 Şubat 2022    Satılık              160  21 Ve Üzeri
#
#               Binanın_Kat_Sayısı        Kullanım_Durumu Yatırıma_Uygunluk  \
# İlan_Numarası
# 2003                       11-20       Kiracı Oturuyor        Bilinmiyor
# 166                          1-5       Kiracı Oturuyor        Bilinmiyor
# 167                          1-5  Mülk Sahibi Oturuyor        Bilinmiyor
# 115                          1-5       Kiracı Oturuyor        Bilinmiyor
# 2879                         1-5  Mülk Sahibi Oturuyor        Bilinmiyor
#
# ...

# %%
data_emlak.columns
# Out:
# Index(['İlan_Güncelleme_Tarihi', 'Kategorisi', 'Brüt_Metrekare',
#        'Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
#        'Yatırıma_Uygunluk', 'Eşya_Durumu', 'Banyo_Sayısı',
#        'İlan_Oluşturma_Tarihi', 'Türü', 'Net_Metrekare', 'Oda_Sayısı',
#        'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
#        'Takas', 'Fiyat_Durumu', 'Fiyatı', 'İl', 'İlçe', 'Mahalle', 'yaka',
#        'Yaşam_endeksi', 'Nüfus'],
#       dtype='object')

# %%
# Gereksiz olan sütunlar silindi

data_emlak.drop('İlan_Güncelleme_Tarihi',axis=1,inplace=True)
data_emlak.drop('İlan_Oluşturma_Tarihi',axis=1,inplace=True)
data_emlak.drop('Türü',axis=1,inplace=True) # Çünkü tüm veriler satılık
data_emlak.drop('İl',axis=1,inplace=True) # Tüm iller İstanbul
data_emlak.drop('Takas',axis=1,inplace=True) # Tüm ilanlar takasa uygun
data_emlak.drop('Kategorisi',axis=1,inplace=True) # Tüm ilanlar satılık
data_emlak.drop('Site_İçerisinde',axis=1,inplace=True) # Verilerin %99.6 ü site içerisinde değil
data_emlak.drop('Yatırıma_Uygunluk',axis=1,inplace=True) # Verilerin %94 ü bilinmiyor
data_emlak.drop('Fiyat_Durumu',axis=1,inplace=True) # Verilerin %97 si genel fiyat
data_emlak.drop('Isıtma_Tipi',axis=1,inplace=True) # Verilerin %97 si doğalgaz
data_emlak.head()
# Out:
#                Brüt_Metrekare  Binanın_Yaşı Binanın_Kat_Sayısı  \
# İlan_Numarası
# 2003                      190         5-10               11-20
# 166                       300  21 Ve Üzeri                 1-5
# 167                       350  21 Ve Üzeri                 1-5
# 115                       450         5-10                 1-5
# 2879                      160  21 Ve Üzeri                 1-5
#
#                      Kullanım_Durumu Eşya_Durumu Banyo_Sayısı  Net_Metrekare  \
# İlan_Numarası
# 2003                Kiracı Oturuyor          Yok            2            168
# 166                 Kiracı Oturuyor          Yok           3             270
# 167            Mülk Sahibi Oturuyor          Yok            2            320
# 115                 Kiracı Oturuyor          Yok           3             400
# 2879           Mülk Sahibi Oturuyor          Yok            1            140
#
#               Oda_Sayısı Bulunduğu_Kat Krediye_Uygunluk    Fiyatı        İlçe  \
# ...

# %%
fiyati = data_emlak['Fiyatı']

data_emlak.loc[:, 'Fiyatı'].astype(int)

data_emlak.loc[fiyati < 1000000, 'Fiyatı'] = 0;
data_emlak.loc[(fiyati >= 1000000) & (fiyati < 2000000), 'Fiyatı'] = 1;
data_emlak.loc[(fiyati >= 2000000) & (fiyati < 3000000), 'Fiyatı'] = 2;
data_emlak.loc[(fiyati >= 3000000) & (fiyati < 4000000), 'Fiyatı'] = 3;
data_emlak.loc[(fiyati >= 4000000) & (fiyati < 5000000), 'Fiyatı'] = 4;
data_emlak.loc[(fiyati >= 5000000) & (fiyati < 6000000), 'Fiyatı'] = 5;
data_emlak.loc[fiyati >= 6000000, 'Fiyatı'] = 6;

# %%
fig = plt.figure(figsize=(10,10))
data_emlak.Fiyatı.value_counts().plot(kind = 'pie',autopct='%.1f%%')
plt.ylabel("", fontsize = 20)
plt.title("Fiyatı");

# %%
data_emlak['Oda_Sayısı'].unique()
sns.countplot(data=data_emlak,x='Oda_Sayısı',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='Oda_Sayısı', ylabel='count'>

# %%
data_emlak['yaka'].unique()
sns.countplot(data=data_emlak,x='yaka',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='yaka', ylabel='count'>

# %%
data_emlak['Yaşam_endeksi'].unique()
sns.countplot(data=data_emlak,x='Yaşam_endeksi',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='Yaşam_endeksi', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(15, 5))
data_emlak['İlçe'].unique()
sns.countplot(data=data_emlak,x='İlçe',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='İlçe', ylabel='count'>

# %%
data_emlak['Binanın_Yaşı'].unique()
sns.countplot(data=data_emlak,x='Binanın_Yaşı',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='Binanın_Yaşı', ylabel='count'>

# %%
data_emlak['Eşya_Durumu'].unique()
sns.countplot(data=data_emlak,x='Eşya_Durumu',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='Eşya_Durumu', ylabel='count'>

# %%
data_emlak['Nüfus'].unique()
sns.countplot(data=data_emlak,x='Nüfus',hue='Fiyatı')
# Out:
# <AxesSubplot: xlabel='Nüfus', ylabel='count'>

# %%
data_emlak.to_csv("df_son.csv")

# %%
df = pd.read_csv("df_son.csv")
df_2 = df.copy()
df_3 = df.copy()
df_2.drop('İlan_Numarası',axis=1,inplace=True)
df_3.drop('İlan_Numarası',axis=1,inplace=True)
df_2
# Out:
#       Brüt_Metrekare  Binanın_Yaşı Binanın_Kat_Sayısı        Kullanım_Durumu  \
# 0                190         5-10               11-20       Kiracı Oturuyor
# 1                300  21 Ve Üzeri                 1-5       Kiracı Oturuyor
# 2                350  21 Ve Üzeri                 1-5  Mülk Sahibi Oturuyor
# 3                450         5-10                 1-5       Kiracı Oturuyor
# 4                160  21 Ve Üzeri                 1-5  Mülk Sahibi Oturuyor
# ...              ...           ...                ...                    ...
# 2977             550  21 Ve Üzeri                 1-5       Kiracı Oturuyor
# 2978             160        16-20                 1-5       Kiracı Oturuyor
# 2979             220        16-20                 1-5       Kiracı Oturuyor
# 2980             950  21 Ve Üzeri                 1-5  Mülk Sahibi Oturuyor
# 2981             250         5-10                 1-5       Kiracı Oturuyor
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
#@title Varsayılan başlık metni
#df_3["Kategorisi"] = le.fit_transform(df_2.Kategorisi)
#df_3["Binanın_Yaşı"] = le.fit_transform(df_2.Binanın_Yaşı)
#df_3["Binanın_Kat_Sayısı"] = le.fit_transform(df_2.Binanın_Kat_Sayısı)
#df_3["Kullanım_Durumu"] = le.fit_transform(df_2.Kullanım_Durumu)
#df_3["Yatırıma_Uygunluk"] = le.fit_transform(df_2.Yatırıma_Uygunluk)
#df_3["Eşya_Durumu"] = le.fit_transform(df_2.Eşya_Durumu)
#df_3["Banyo_Sayısı"] = le.fit_transform(df_2.Banyo_Sayısı)
#df_3["Oda_Sayısı"] = le.fit_transform(df_2.Oda_Sayısı)
#df_3["Bulunduğu_Kat"] = le.fit_transform(df_2.Bulunduğu_Kat)
#df_3["Isıtma_Tipi"] = le.fit_transform(df_2.Isıtma_Tipi)
#df_3["Krediye_Uygunluk"] = le.fit_transform(df_2.Krediye_Uygunluk)
#df_3["Site_İçerisinde"] = le.fit_transform(df_2.Site_İçerisinde)
#df_3["Fiyat_Durumu"] = le.fit_transform(df_2.Fiyat_Durumu)
#df_3["Mahalle"] = le.fit_transform(df_2.Mahalle)
#df_3["yaka"] = le.fit_transform(df_2.yaka)
#df_3["Yaşam_endeksi"] = le.fit_transform(df_2.Yaşam_endeksi)
#df_3["Nüfus"] = le.fit_transform(df_2.Nüfus)
df_3['Banyo_Sayısı'] = df_3['Banyo_Sayısı'].astype(str)
df_3['Bulunduğu_Kat'] = df_3['Bulunduğu_Kat'].astype(str)

columns=["Binanın_Yaşı","Binanın_Kat_Sayısı","Kullanım_Durumu",
         "Eşya_Durumu","Banyo_Sayısı","Oda_Sayısı","Bulunduğu_Kat","Krediye_Uygunluk","Mahalle","yaka","İlçe"]

# %%
for feature in columns:
  df_3[feature]=encoder.fit_transform(df_3[feature])
df_3.head()
# Out:
#    Brüt_Metrekare  Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  \
# 0             190             4                   1                1
# 1             300             3                   0                1
# 2             350             3                   0                2
# 3             450             4                   0                1
# 4             160             3                   0                2
#
#    Eşya_Durumu  Banyo_Sayısı  Net_Metrekare  Oda_Sayısı  Bulunduğu_Kat  \
# 0            1             2            168           3              3
# 1            1             3            270           4             12
# 2            1             2            320           4             13
# 3            1             3            400           4             13
# 4            1             1            140           2              3
#
#    Krediye_Uygunluk  Fiyatı  İlçe  Mahalle  yaka  Yaşam_endeksi   Nüfus
# ...

# %%
df_3.to_csv("df_ml.csv")

# %%
df_ml = pd.read_csv("df_ml.csv")
df_ml.drop("Unnamed: 0",axis=1,inplace=True )
df_ml
# Out:
#       Brüt_Metrekare  Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  \
# 0                190             4                   1                1
# 1                300             3                   0                1
# 2                350             3                   0                2
# 3                450             4                   0                1
# 4                160             3                   0                2
# ...              ...           ...                 ...              ...
# 2977             550             3                   0                1
# 2978             160             2                   0                1
# 2979             220             2                   0                1
# 2980             950             3                   0                2
# 2981             250             4                   0                1
#
#       Eşya_Durumu  Banyo_Sayısı  Net_Metrekare  Oda_Sayısı  Bulunduğu_Kat  \
# ...

# %% [markdown]
# ### ***ML***

# %%
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2982 entries, 0 to 2981
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brüt_Metrekare      2982 non-null   int64
#  1   Binanın_Yaşı        2982 non-null   int64
#  2   Binanın_Kat_Sayısı  2982 non-null   int64
#  3   Kullanım_Durumu     2982 non-null   int64
#  4   Eşya_Durumu         2982 non-null   int64
#  5   Banyo_Sayısı        2982 non-null   int64
#  6   Net_Metrekare       2982 non-null   int64
#  7   Oda_Sayısı          2982 non-null   int64
#  8   Bulunduğu_Kat       2982 non-null   int64
#  9   Krediye_Uygunluk    2982 non-null   int64
#  10  Fiyatı              2982 non-null   int64
#  11  İlçe                2982 non-null   int64
#  12  Mahalle             2982 non-null   int64
#  13  yaka                2982 non-null   int64
#  14  Yaşam_endeksi       2982 non-null   float64
#  15  Nüfus               2982 non-null   float64
# ...

# %%
df_ml.corr()
fig,ax=plt.subplots(figsize=(28,20))
sns.heatmap(df_ml.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df_ml.Fiyatı
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       4
#        ..
# 2977    6
# 2978    2
# 2979    6
# 2980    4
# 2981    3
# Name: Fiyatı, Length: 2982, dtype: int64

# %%
from pandas import arrays
#df_ml = df_ml.set_index(pd.IntervalIndex.from_arrays(df_ml['0'], df_ml['5000000']))['0-5M']
#df_ml.loc[(df_ml['Fiyatı']>0 | df_ml['Fiyatı']<5000000),"Fiyatı"] = "0-5M"
#data_emlak["Yatırıma_Uygunluk"] = data_emlak["Yatırıma_Uygunluk"].str.replace('Evet', 'Yatırıma Uygun',regex=True)
#df_2.loc[df_2.aidat == "Belirtilmemiş", "aidat"] = "0 TL"

# %%
y=df_ml.pop('Fiyatı')
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       4
#        ..
# 2977    6
# 2978    2
# 2979    6
# 2980    4
# 2981    3
# Name: Fiyatı, Length: 2982, dtype: int64

# %%
X=df_ml.to_numpy()
X
# Out:
# array([[1.90000e+02, 4.00000e+00, 1.00000e+00, ..., 1.00000e+00,
#         9.11000e-01, 1.78938e+02],
#        [3.00000e+02, 3.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         9.11000e-01, 1.78938e+02],
#        [3.50000e+02, 3.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         9.11000e-01, 1.78938e+02],
#        ...,
#        [2.20000e+02, 2.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         3.47000e-01, 3.49968e+02],
#        [9.50000e+02, 3.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         3.47000e-01, 3.49968e+02],
#        [2.50000e+02, 4.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         3.47000e-01, 3.49968e+02]])

# %%
plt.hist(y)
# Out:
# (array([915., 767.,   0., 348.,   0., 239., 172.,   0.,  86., 455.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
# COMMON MODULES
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# LOGISTIC REGRESSION

# 0. IMPORT
from sklearn.linear_model import LogisticRegression

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
lr = LogisticRegression(solver='lbfgs', max_iter=3000)
lr.fit(X_train, y_train)

# 3. PREDICT
y_pred = lr.predict(X_test)

# 4. EVALUATE
accuracy_lr = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_lr)
# Out:
# Accuracy: 0.5108877721943048
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# SVM

# 0. IMPORT
from sklearn.preprocessing import StandardScaler
from sklearn import svm

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
svc = svm.SVC()
svc.fit(X_train, y_train)

# 3. PREDICT
y_pred = svc.predict(X_test)

# 4. EVALUATE
accuracy_svc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_svc)
# Out:
# Accuracy: 0.4438860971524288

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
kn = KNeighborsClassifier(n_neighbors=4)
kn.fit(X_train, y_train)

# 3. PREDICT
y_pred = kn.predict(X_test)

# 4. EVALUATE
accuracy_kn = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_kn)
# Out:
# Accuracy: 0.48408710217755446

# %%
# DecisionTreeClassifier

# 0. IMPORT
import sklearn.tree as tree

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
decision_tree = tree.DecisionTreeClassifier(class_weight='balanced')
decision_tree.fit(X_train, y_train)

# 3. PREDICT
y_pred = decision_tree.predict(X_test)

# 4. EVALUATE
accuracy_dtc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_dtc)
# Out:
# Accuracy: 0.49748743718592964

# %%
# RandomForestClassifier

# 0. IMPORT
from sklearn.ensemble import RandomForestClassifier

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# 3. PREDICT
y_pred = rfc.predict(X_test)

# 4. EVALUATE
accuracy_rfc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_rfc)
# Out:
# Accuracy: 0.5661641541038526

# %%
# Gaussian Naive Bayes

# 0. IMPORT
from sklearn.naive_bayes import GaussianNB

# 1. SPLIT
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# 2. TRAIN
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# 3. PREDICT
y_pred = gnb.predict(X_test)

# 4. EVALUATE
accuracy_gnb = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_gnb)
# Out:
# Accuracy: 0.4493628437290409

# %%
# Comparing Models

models = pd.DataFrame({
    'Model': ['LogisticRegression', 'RandomForestClassifier', 'SVM Classifier', 'DecisionTreeClassifier', 'GaussianNaiveBayes', 'K-NearestNeightbors'],
    'Accuracy': [accuracy_lr*100, accuracy_rfc*100, accuracy_svc*100, accuracy_dtc*100, accuracy_gnb * 100, accuracy_kn * 100 ]})
models.sort_values(by='Accuracy', ascending=False)
# Out:
#                     Model  Accuracy
# 1  RandomForestClassifier    56.616
# 0      LogisticRegression    51.089
# 3  DecisionTreeClassifier    49.749
# 5     K-NearestNeightbors    48.409
# 4      GaussianNaiveBayes    44.936
# 2          SVM Classifier    44.389

# %%
# MODELİ İYİLEŞTİRME
# ADIM 1: DOLAR KURU EKLEME

# https://tr.investing.com/currencies/usd-try-historical-data
# birebir maplenebilir olmasi icin 2020-2022 arasini alacagiz

pd.set_option('mode.chained_assignment', None)

kur_df = pd.read_csv("USD_TRY Geçmiş Verileri.csv")

# resample (converting to pandas compatible datetime)
kur_df['Tarih'] = pd.to_datetime(kur_df['Tarih'], dayfirst=True)

#
kur_df = kur_df.loc[:, ['Tarih', 'Şimdi']]
kur_df.rename({'Şimdi': "Dolar_Kuru"}, axis='columns', inplace=True)

kur_df # bunda eksik tarihler var haftasonlari vb. asagidaki adimlar o eksikleri tamamlamak icin
# Out:
#          Tarih Dolar_Kuru
# 0   2022-12-30    18,6883
# 1   2022-12-29    18,6941
# 2   2022-12-28    18,7157
# 3   2022-12-27    18,6669
# 4   2022-12-26    18,6618
# ..         ...        ...
# 778 2020-01-07     5,9705
# 779 2020-01-06     5,9644
# 780 2020-01-03     5,9713
# 781 2020-01-02     5,9541
# 782 2020-01-01     5,9456
#
# [783 rows x 2 columns]

# %%
tmp = pd.DataFrame(pd.date_range(start=min(kur_df['Tarih']), end=max(kur_df['Tarih'])))
tmp.rename({0: "Tarih"}, axis='columns', inplace=True)
tmp # bunu olusturmanin amaci eksik tarihleri gidermek
# Out:
#           Tarih
# 0    2020-01-01
# 1    2020-01-02
# 2    2020-01-03
# 3    2020-01-04
# 4    2020-01-05
# ...         ...
# 1090 2022-12-26
# 1091 2022-12-27
# 1092 2022-12-28
# 1093 2022-12-29
# 1094 2022-12-30
#
# [1095 rows x 1 columns]

# %%
new_df = pd.merge(kur_df, tmp, on='Tarih', how='right')

# Forward Filling
new_df['Dolar_Kuru'].fillna(method = 'ffill', inplace = True)

# 01-01-2020 ve 31-12-2022 arasi tum dolar kurlarini iceren dataframe
new_df
# Out:
#           Tarih Dolar_Kuru
# 0    2020-01-01     5,9456
# 1    2020-01-02     5,9541
# 2    2020-01-03     5,9713
# 3    2020-01-04     5,9713
# 4    2020-01-05     5,9713
# ...         ...        ...
# 1090 2022-12-26    18,6618
# 1091 2022-12-27    18,6669
# 1092 2022-12-28    18,7157
# 1093 2022-12-29    18,6941
# 1094 2022-12-30    18,6883
#
# [1095 rows x 2 columns]

# %%
data_emlak = pd.read_csv("Real Estate in ISTANBUL (Emlakjet).csv",index_col=0)
data_emlak
# Out:
#               İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  Binanın_Yaşı  \
# İlan_Numarası
# 2003                  02 Şubat 2022    Satılık              190         5-10
# 166                    14 Ocak 2022    Satılık              300  21 Ve Üzeri
# 167                    14 Ocak 2022    Satılık              350  21 Ve Üzeri
# 115                    06 Ocak 2022    Satılık              450         5-10
# 2879                  08 Şubat 2022    Satılık              160  21 Ve Üzeri
# ...                              ...        ...             ...           ...
# 453                  16 Aralık 2021    Satılık              550  21 Ve Üzeri
# 448                  16 Aralık 2021    Satılık              160        16-20
# 451                  28 Aralık 2021    Satılık              220        16-20
# 454                  28 Aralık 2021    Satılık              950  21 Ve Üzeri
# 452                    03 Ocak 2022    Satılık              250         5-10
#
# ...

# %%
data_emlak['İlan_Güncelleme_Tarihi'] =  data_emlak['İlan_Güncelleme_Tarihi'].astype('string')

# tarih lokalizasyonu
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Ocak ','-01-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Şubat ','-02-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Mart ','-03-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Nisan ','-04-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Mayıs ','-05-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Haziran ','-06-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Temmuz ','-07-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Ağustos ','-08-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Eylül ','-09-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Ekim ','-10-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Kasım ','-11-')
data_emlak['İlan_Güncelleme_Tarihi'] = data_emlak['İlan_Güncelleme_Tarihi'].str.replace(' Aralık ','-12-')

# string tipini date-time'a cevirme
data_emlak['İlan_Güncelleme_Tarihi'] = pd.to_datetime(data_emlak['İlan_Güncelleme_Tarihi'])

data_emlak
# Out:
#               İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  Binanın_Yaşı  \
# İlan_Numarası
# 2003                      2022-02-02   Satılık              190         5-10
# 166                       2022-01-14   Satılık              300  21 Ve Üzeri
# 167                       2022-01-14   Satılık              350  21 Ve Üzeri
# 115                       2022-06-01   Satılık              450         5-10
# 2879                      2022-08-02   Satılık              160  21 Ve Üzeri
# ...                              ...        ...             ...           ...
# 453                       2021-12-16   Satılık              550  21 Ve Üzeri
# 448                       2021-12-16   Satılık              160        16-20
# 451                       2021-12-28   Satılık              220        16-20
# 454                       2021-12-28   Satılık              950  21 Ve Üzeri
# 452                       2022-03-01   Satılık              250         5-10
#
# ...

# %%
# dk_data_emlak = dolar kurlu data emlak
dk_data_emlak = pd.merge(new_df, data_emlak, left_on='Tarih', right_on='İlan_Güncelleme_Tarihi', how='right')

pd.set_option('display.float_format', lambda x: '%.3f' % x)

# model uyumlulugu icin data tipi float'a cevriliyor
dk_data_emlak['Dolar_Kuru'] = dk_data_emlak['Dolar_Kuru'].str.replace(",", ".")
dk_data_emlak['Dolar_Kuru'] = dk_data_emlak['Dolar_Kuru'].astype(float)

dk_data_emlak['Dolar_Fiyati'] = dk_data_emlak['Fiyatı'] / dk_data_emlak['Dolar_Kuru']
dk_data_emlak['Dolar_Fiyati'] = dk_data_emlak['Dolar_Fiyati'].astype(int) # removing decimals

dk_data_emlak
# Out:
#           Tarih  Dolar_Kuru İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  \
# 0    2022-02-02      13.453             2022-02-02   Satılık              190
# 1    2022-01-14      13.521             2022-01-14   Satılık              300
# 2    2022-01-14      13.521             2022-01-14   Satılık              350
# 3    2022-06-01      16.381             2022-06-01   Satılık              450
# 4    2022-08-02      17.925             2022-08-02   Satılık              160
# ...         ...         ...                    ...        ...             ...
# 2978 2021-12-16      15.667             2021-12-16   Satılık              550
# 2979 2021-12-16      15.667             2021-12-16   Satılık              160
# 2980 2021-12-28      11.798             2021-12-28   Satılık              220
# 2981 2021-12-28      11.798             2021-12-28   Satılık              950
# 2982 2022-03-01      13.916             2022-03-01   Satılık              250
#
# ...

# %%
fiyatlar = dk_data_emlak['Dolar_Fiyati']
dk_data_emlak.describe()
# Out:
#        Dolar_Kuru  Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare  \
# count    2983.000        2983.000            2983.000       2983.000
# mean       14.514         169.343               8.670        145.347
# std         2.525         373.361               7.092        370.483
# min         7.024          35.000               1.000          1.000
# 25%        13.423         100.000               4.000         84.000
# 50%        13.560         130.000               5.000        106.000
# 75%        16.761         180.000              11.000        150.000
# max        18.631       13500.000              44.000      13499.000
#
#               Fiyatı  Yaşam_endeksi    Nüfus  Dolar_Fiyati
# count       2983.000       2983.000 2983.000      2983.000
# mean     5221565.564          0.212  512.160    387903.825
# std     37167172.383          0.402  206.820   2745585.326
# min       169000.000         -0.194  178.938     10727.000
# ...

# %%
dolar_fiyati = dk_data_emlak['Dolar_Fiyati']

q_low = dk_data_emlak["Dolar_Fiyati"].quantile(0.1)
q_hi  = dk_data_emlak["Dolar_Fiyati"].quantile(0.9)

df_filtered = dk_data_emlak[(dk_data_emlak["Dolar_Fiyati"] < q_hi) & (dk_data_emlak["Dolar_Fiyati"] > q_low)]

df_filtered.describe()
# Out:
#        Dolar_Kuru  Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare  \
# count    2385.000        2385.000            2385.000       2385.000
# mean       14.528         152.958               8.826        130.371
# std         2.462         293.438               6.998        291.022
# min         7.024          42.000               1.000         25.000
# 25%        13.423         100.000               4.000         84.000
# 50%        13.560         128.000               5.000        105.000
# 75%        16.761         165.000              11.000        140.000
# max        18.631       13500.000              34.000      13499.000
#
#             Fiyatı  Yaşam_endeksi    Nüfus  Dolar_Fiyati
# count     2385.000       2385.000 2385.000      2385.000
# mean   2360357.309          0.190  518.865    166315.242
# std    1847261.038          0.387  187.509    131070.744
# min     395000.000         -0.194  178.938     39058.000
# 25%     985000.000         -0.152  398.122     68458.000
# ...

# %%
# Change values
df_filtered.loc[dolar_fiyati < 50000, 'Dolar_Fiyati'] = 0;
df_filtered.loc[(dolar_fiyati >= 50000) & (dolar_fiyati < 100000), 'Dolar_Fiyati'] = 1;
df_filtered.loc[(dolar_fiyati >= 100000) & (dolar_fiyati < 150000), 'Dolar_Fiyati'] = 2;
df_filtered.loc[(dolar_fiyati >= 150000) & (dolar_fiyati < 200000), 'Dolar_Fiyati'] = 3;
df_filtered.loc[(dolar_fiyati >= 200000) & (dolar_fiyati < 250000), 'Dolar_Fiyati'] = 4;
df_filtered.loc[(dolar_fiyati >= 250000) & (dolar_fiyati < 300000), 'Dolar_Fiyati'] = 5;
df_filtered.loc[dolar_fiyati >= 300000, 'Dolar_Fiyati'] = 6;

# Gereksiz sutunlari silme
df_filtered.drop("Dolar_Kuru", axis=1, inplace=True)
df_filtered.drop('İlan_Güncelleme_Tarihi',axis=1,inplace=True)
df_filtered.drop('İlan_Oluşturma_Tarihi',axis=1,inplace=True)
df_filtered.drop('Türü',axis=1,inplace=True) # Çünkü tüm veriler satılık
df_filtered.drop('İl',axis=1,inplace=True) # Tüm iller İstanbul
df_filtered.drop('Takas',axis=1,inplace=True) # Tüm ilanlar takasa uygun
df_filtered.drop('Kategorisi',axis=1,inplace=True) # Tüm ilanlar satılık
df_filtered.drop('Site_İçerisinde',axis=1,inplace=True) # Verilerin %99.6 ü site içerisinde değil
df_filtered.drop('Yatırıma_Uygunluk',axis=1,inplace=True) # Verilerin %94 ü bilinmiyor
df_filtered.drop('Fiyat_Durumu',axis=1,inplace=True) # Verilerin %97 si genel fiyat
df_filtered.drop('Isıtma_Tipi',axis=1,inplace=True) # Verilerin %97 si doğalgaz
df_filtered.drop('Tarih',axis=1,inplace=True) # Tarih

# %%
import numpy as np
# Fiyat kategorilerinde kacar adet var kontrolu
np.histogram(df_filtered['Dolar_Fiyati'], bins=[0, 1, 2, 3, 4, 5, 6])
# Out:
# (array([225, 808, 410, 254, 185, 503]), array([0, 1, 2, 3, 4, 5, 6]))

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df_filtered['Banyo_Sayısı'] = df_3['Banyo_Sayısı'].astype(str)
df_filtered['Bulunduğu_Kat'] = df_3['Bulunduğu_Kat'].astype(str)

columns=["Binanın_Yaşı","Binanın_Kat_Sayısı","Kullanım_Durumu",
         "Eşya_Durumu","Banyo_Sayısı","Oda_Sayısı","Bulunduğu_Kat","Krediye_Uygunluk","Mahalle","yaka","İlçe"]



for feature in columns:
  df_filtered[feature]=encoder.fit_transform(df_filtered[feature])
df_filtered.head()
# Out:
#    Brüt_Metrekare  Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  \
# 4             160             5                   1                2
# 5              65             5                   3                2
# 7              90             5                   6                2
# 8             160             5                   8                2
# 9             190             3                   4                2
#
#    Eşya_Durumu  Banyo_Sayısı  Net_Metrekare  Oda_Sayısı  Bulunduğu_Kat  \
# 4            1             1            140           7             12
# 5            1             1             55           4              4
# 7            1             1             85           4              4
# 8            1             1            130           7              3
# 9            1             2            170          10             14
#
#    Krediye_Uygunluk   Fiyatı  İlçe  Mahalle  yaka  Yaşam_endeksi   Nüfus  \
# ...

# %%
# Ortak moduller
from sklearn.model_selection import train_test_split
from sklearn import metrics

y = df_filtered.pop('Dolar_Fiyati')
X = df_filtered.to_numpy()
y.describe()
# Out:
# count   2385.000
# mean       2.526
# std        1.967
# min        0.000
# 25%        1.000
# 50%        2.000
# 75%        4.000
# max        6.000
# Name: Dolar_Fiyati, dtype: float64

# %%
# LOGISTIC REGRESSION

# 0. IMPORT
from sklearn.linear_model import LogisticRegression

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
lr = LogisticRegression(solver='lbfgs', max_iter=3000)
lr.fit(X_train, y_train)

# 3. PREDICT
y_pred = lr.predict(X_test)

# 4. EVALUATE
accuracy_lr = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_lr)
# Out:
# Accuracy: 0.5807127882599581

# %%
# SVM

# 0. IMPORT
from sklearn.preprocessing import StandardScaler
from sklearn import svm

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
svc = svm.SVC()
svc.fit(X_train, y_train)

# 3. PREDICT
y_pred = svc.predict(X_test)

# 4. EVALUATE
accuracy_svc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_svc)
# Out:
# Accuracy: 0.6645702306079665

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
kn = KNeighborsClassifier(n_neighbors=4)
kn.fit(X_train, y_train)

# 3. PREDICT
y_pred = kn.predict(X_test)

# 4. EVALUATE
accuracy_kn = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_kn)
# Out:
# Accuracy: 0.6582809224318659

# %%
# DecisionTreeClassifier

# 0. IMPORT
import sklearn.tree as tree

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
decision_tree = tree.DecisionTreeClassifier(class_weight='balanced')
decision_tree.fit(X_train, y_train)

# 3. PREDICT
y_pred = decision_tree.predict(X_test)

# 4. EVALUATE
accuracy_dtc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_dtc)
# Out:
# Accuracy: 0.6373165618448637

# %%
# Gaussian Naive Bayes

# 0. IMPORT
from sklearn.naive_bayes import GaussianNB

# 1. SPLIT
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# 2. TRAIN
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# 3. PREDICT
y_pred = gnb.predict(X_test)

# 4. EVALUATE
accuracy_gnb = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_gnb)
# Out:
# Accuracy: 0.4543168482816429

# %%
# RandomForestClassifier

# 0. IMPORT
from sklearn.ensemble import RandomForestClassifier

# 1. SPLIT
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2)

# 2. TRAIN
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# 3. PREDICT
y_pred = rfc.predict(X_test)

# 4. EVALUATE
accuracy_rfc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_rfc)
# Out:
# Accuracy: 0.7169811320754716

# %%
# Comparing Models

models = pd.DataFrame({
    'Model': ['LogisticRegression', 'RandomForestClassifier', 'SVM Classifier', 'DecisionTreeClassifier', 'GaussianNaiveBayes', 'K-NearestNeightbors'],
    'Accuracy': [accuracy_lr*100, accuracy_rfc*100, accuracy_svc*100, accuracy_dtc*100, accuracy_gnb * 100, accuracy_kn * 100 ]})
models.sort_values(by='Accuracy', ascending=False)
# Out:
#                     Model  Accuracy
# 1  RandomForestClassifier    71.698
# 2          SVM Classifier    66.457
# 5     K-NearestNeightbors    65.828
# 3  DecisionTreeClassifier    63.732
# 0      LogisticRegression    58.071
# 4      GaussianNaiveBayes    45.432

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69        45
#            1       0.83      0.86      0.84       161
#            2       0.63      0.71      0.67        82
#            3       0.43      0.51      0.47        51
#            4       0.45      0.27      0.34        37
#            5       0.75      0.24      0.36        25
#            6       0.84      0.97      0.90        76
#
#     accuracy                           0.72       477
#    macro avg       0.67      0.60      0.61       477
# weighted avg       0.71      0.72      0.70       477
